# %% [markdown]
# ---
#
# ## 🧾 **PIP Command Cheat Sheet (Jupyter + Terminal)**
#
# ### 🧠 1. `pip install package_name`
#
# * **Runs in:** 🖥️ Terminal / Command Prompt
# * **Works in Jupyter:** ❌ No
# * **Environment:** ✅ Installs in the current Python environment
# * **Recommended for:** Installing packages outside Jupyter
# * **Reason:** Standard CLI tool; safest for system-wide or virtualenv installs.
#
# ---
#
# ### ⚙️ 2. `!pip install package_name`
#
# * **Runs in:** ⚡ Shell command (via `!` in Jupyter)
# * **Works in Jupyter:** ✅ Yes
# * **Environment:** ⚠️ Might install in a different environment (not always the same as the kernel)
# * **Recommended for:** Temporary installs when `%pip` is unavailable
# * **Reason:** Executes as an OS command, not Python-aware — can mismatch environments.
#
# ---
#
# ### 🪄 3. `%pip install package_name`
#
# * **Runs in:** 🧩 IPython Magic (inside Jupyter)
# * **Works in Jupyter:** ✅ Yes
# * **Environment:** ✅ Installs in the **same environment as the notebook kernel**
# * **Recommended for:** 💯 Best and safest way inside Jupyter notebooks
# * **Reason:** IPython manages it to match your active kernel — no mismatch risk.
#
# ---
#
# ### 💡 **Quick Summary Table**
#
# | Command        | Works in Jupyter | Same Environment | Best Used In       | Notes                             |
# | -------------- | ---------------- | ---------------- | ------------------ | --------------------------------- |
# | `pip install`  | ❌ No             | ✅ Yes            | Terminal           | Standard Python package installer |
# | `!pip install` | ✅ Yes            | ⚠️ Not always    | Jupyter (fallback) | Runs as shell command             |
# | `%pip install` | ✅ Yes            | ✅ Yes            | 🏆 Jupyter         | Safe, kernel-aware IPython magic  |
#
# ---
